# %%
from ioncast import *
from torch.utils.data import DataLoader
import datetime

# %%
# Create sequence dataset
gim_dir = "/mnt/ionosphere-data/jpld/webdataset"
omni_dir = "/mnt/ionosphere-data/omniweb/cleaned"

date_start = datetime.datetime(2022, 1, 1)
date_end = datetime.datetime(2022, 7, 31)

gim_dataset = JPLDGIMDataset(
    data_dir=gim_dir,
    date_start=date_start,
    date_end=date_end,
)

omni_dataset = OMNIDataset(
    data_dir=omni_dir,
    date_start=date_start,
    date_end=date_end,
)

sequence_dataset = Sequences([gim_dataset, omni_dataset], delta_minutes=15, sequence_length=10)
# Out:
# JPLD
# Directory  : /mnt/ionosphere-data/jpld/webdataset
# Loading tar files index from cache: /mnt/ionosphere-data/jpld/webdataset/tar_files_index
# Start date : 2022-01-01 00:00:00
# End date   : 2022-07-31 00:00:00
# Delta      : 15 minutes
# Filtering dates: 100%|██████████| 20256/20256 [00:00<00:00, 202256.88it/s]
# Saving dates to cache: /mnt/ionosphere-data/jpld/webdataset/dates_index_2022-01-01T00:00:00_2022-07-31T00:00:00
# TEC maps total    : 20,256
# TEC maps available: 20,256
# TEC maps dropped  : 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 14
#       6 date_end = datetime.datetime(2022, 7, 31)
#       8 gim_dataset = JPLDGIMDataset(
#       9     data_dir=gim_dir,
#      10     date_start=date_start,
#      11     date_end=date_end,
#      12 )
# ---> 14 omni_dataset = OMNIDataset(
#      15     data_dir=omni_dir,
#      16     date_start=date_start,
#      17     date_end=date_end,
#      18 )
#      20 sequence_dataset = Sequences([gim_dataset, omni_dataset], delta_minutes=15, sequence_length=10)
#
# TypeError: OMNIDataset.__init__() got an unexpected keyword argument 'data_dir'

# %%
# Batch into 5 using a DataLoader
dataloader = DataLoader(
    sequence_dataset,
    batch_size=5,
)
