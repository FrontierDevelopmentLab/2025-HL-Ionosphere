# %%
import src
import datetime

# %%
# Test CelestrakDataset class
from src import CelestrakDataset

data_file = "/mnt/ionosphere-data/celestrak/kp_ap_processed_timeseries.csv"
celestrak = CelestrakDataset(data_file=data_file, normalize=True)
# Out:
# Celestrak Dataset
# Head of data file:
#
#                            Kp        Ap
# Datetime
# 1957-10-01 00:00:00  1.531564  1.012923
# 1957-10-01 03:00:00  1.317561  0.747159
# 1957-10-01 06:00:00  0.604218  0.109327
# 1957-10-01 09:00:00 -0.109126 -0.315895
# 1957-10-01 12:00:00  1.103558  0.481396
#
# Checking date range of data in file: /mnt/ionosphere-data/celestrak/kp_ap_processed_timeseries.csv
# Start date : 1957-10-01 00:00:00
# End date   : 2025-08-14 21:00:00
# Number of days in dataset   : 24,790
# Number of samples in dataset: 198,320
# Size on disk                : 0.01 GB

# %%
# Test the get_item method. Index with datetime
date = datetime.datetime.strptime("2024-01-01 00:00:00", '%Y-%m-%d %H:%M:%S')
data = celestrak[date]
print(f"Data for {date}: {data}")

index = 2000  # Example index
data_by_index = celestrak[index]
print(f"Data for index {index}: {data_by_index}")
# Out:
# Data for 2024-01-01 00:00:00: (tensor([-1.0365, -0.5285]), '2024-01-01T00:00:00')
# Data for index 2000: (tensor([-0.6085, -0.4222]), '1958-06-08T00:00:00')

# %%
# Test CelestrakDataset class
from src import SolarIndexDataset

data_file = "/mnt/ionosphere-data/solar_env_tech_indices/Indices_F10_processed.csv"
solarindex = SolarIndexDataset(data_file=data_file, normalize=True)
# Out:
# Solar Index Dataset
# Head of data file:
#
#                           F10       S10       M10       Y10
# Datetime
# 1997-01-01 00:00:00 -0.926921 -0.809490 -1.125395 -1.313040
# 1997-01-02 00:00:00 -0.933731 -0.814066 -1.090526 -1.275538
# 1997-01-03 00:00:00 -0.906491 -0.786610 -1.016137 -1.238035
# 1997-01-04 00:00:00 -0.895141 -0.756866 -0.981268 -1.223034
# 1997-01-05 00:00:00 -0.881520 -0.727122 -0.962671 -1.193032
#
# Checking date range of data in file: /mnt/ionosphere-data/solar_env_tech_indices/Indices_F10_processed.csv
# Start date : 1997-01-01 00:00:00
# End date   : 2025-09-13 00:00:00
# Number of days in dataset   : 10,483
# Number of samples in dataset: 10,483
# Size on disk                : 0.00 GB

# %%
# Test the get_item method. Index with datetime
date = datetime.datetime.strptime("2024-01-01 00:00:00", '%Y-%m-%d %H:%M:%S')
data = solarindex[date]
print(f"Data for {date}: {data}")

index = 2000  # Example index
data_by_index = solarindex[index]
print(f"Data for index {index}: {data_by_index}")
# Out:
# Data for 2024-01-01 00:00:00: (tensor([0.4079, 0.6434, 0.8017, 1.1246]), '2024-01-01T00:00:00')
# Data for index 2000: (tensor([0.8414, 1.2360, 1.2271, 1.0771]), '2002-06-24T00:00:00')
