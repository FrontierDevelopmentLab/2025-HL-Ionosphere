# %%
import src
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import src
#
# File ~/ionosphere/2025-HL-Ionosphere/src/__init__.py:1
# ----> 1 from .gim_dataset import *
#
# File ~/ionosphere/2025-HL-Ionosphere/src/gim_dataset.py:1
# ----> 1 import torch
#       2 from torch.utils.data import Dataset
#       3 from glob import glob
#
# ModuleNotFoundError: No module named 'torch'
