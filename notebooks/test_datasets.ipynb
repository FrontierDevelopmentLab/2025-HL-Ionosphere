# %%
import src
import datetime

# %%
# Test CelestrakDataset class
from src.celestrak_dataset import CelestrakDataset

data_file = "/mnt/ionosphere-data/celestrak/kp_ap_timeseries_processed.csv"
celestrak = CelestrakDataset(data_file=data_file, normalize=True

# %%
# Test the get_item method. Index with datetime
date = datetime.datetime.strptime("2024-01-01 00:00:00", '%Y-%m-%d %H:%M:%S')
data = celestrak[date]
print(f"Data for {date}: {data}")

index = 2000  # Example index
data_by_index = celestrak[index]
print(f"Data for index {index}: {data_by_index}")
# Out:
# Index in DataFrame: 193584, Date: 2024-01-01 00:00:00, value: [-0.99783527 -0.52037441]
# Data for 2024-01-01 00:00:00: tensor([-0.9978, -0.5204])
# Index in DataFrame: 2000, Date: 1958-06-08 00:00:00, value: [-0.57858851 -0.41445464]
# Data for index 2000: tensor([-0.5786, -0.4145])

# %%
# Test CelestrakDataset class
from src.solar_indices_dataset import CelestrakDataset

data_file = "/mnt/ionosphere-data/celestrak/Indices_F10_processed.csv"
celestrak = CelestrakDataset(data_file=data_file, normalize=True)
